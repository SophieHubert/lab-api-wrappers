# %% [markdown]
# <h1>Table<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # 1- Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

import spotipy.util as util

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="af3a4e21d9974f798b0ddef081728f2b",
                                                           client_secret="99a65d20eff04d64bcf24b11824dffc4"))

# %%
sp.user_playlist_tracks("spotify", "5B7ozQ0Led4tEcXc4ql71j")
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5B7ozQ0Led4tEcXc4ql71j/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2020-12-21T15:02:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/213hucjuedofdkaaqgqqsimoy'},
#     'href': 'https://api.spotify.com/v1/users/213hucjuedofdkaaqgqqsimoy',
#     'id': '213hucjuedofdkaaqgqqsimoy',
#     'type': 'user',
#     'uri': 'spotify:user:213hucjuedofdkaaqgqqsimoy'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lB8vOoI4DRrrVxXwuV19c'},
#        'href': 'https://api.spotify.com/v1/artists/6lB8vOoI4DRrrVxXwuV19c',
#        'id': '6lB8vOoI4DRrrVxXwuV19c',
#        'name': 'Mike Perry',
#        'type': 'artist',
#        'uri': 'spotify:artist:6lB8vOoI4DRrrVxXwuV19c'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
# ...

# %%
playlist_creator = "spotify"
playlist_id = "5B7ozQ0Led4tEcXc4ql71j"

# %%
track_names = [track['track']['name'] for track in tracks]
track_names
# Out:
# ['The Ocean (feat. Shy Martin)',
#  'Dive',
#  'Far Away From Home (feat. Leony)',
#  'In Your Eyes (feat. Alida)',
#  'All We Got (feat. KIDDO) - Ofenbach Remix',
#  'Coming Home',
#  'Waiting For Love',
#  'Soldier',
#  'Where We Come Alive',
#  'Tonight I Run',
#  'Opera #2',
#  'Les enfants du monde',
#  "Arrietty's Song",
#  'Soldiers',
#  'Astronomia - Piano & Kick Drum',
#  'Shelter',
#  'Let Me Love You',
#  'That Girl',
#  'Heads Will Roll',
#  "Devil's Worst Nightmare",
#  'Fight Forever',
#  "What's Up?",
#  "Can't Help Falling In Love - DARK",
#  'In The End',
#  'Scared of the Dark',
#  'Fire',
#  'Carry On']

# %%
artists = get_artists_from_playlist("5B7ozQ0Led4tEcXc4ql71j")
artists
# Out:
# ['Robin Schulz',
#  'KIDDO',
#  'Astræa',
#  'Ruelle',
#  'Jung Youth',
#  'Avicii',
#  'Alida',
#  'FJØRA',
#  'Mike Perry',
#  'Tommee Profitt',
#  'Coasts',
#  'Peter Bence',
#  'The Score',
#  'Sam Feldt',
#  'Fleurie',
#  'VIZE',
#  'Dimitri Vangelis & Wyman',
#  'EQRIC',
#  'brooke',
#  'Chris James',
#  'Erza Muqoli',
#  'Unread',
#  'The Satellite Station',
#  'Leony',
#  'Steps',
#  'Anna of the North',
#  'Shyloom',
#  'AWOLNATION',
#  'YOHIO',
#  'Neoni',
#  'Olly Murs',
#  'SHY Martin',
#  'Cécile Corbel',
#  'Ofenbach',
#  'Hot Shade']

# %%
track_ids = [track['track']['id'] for track in tracks]
track_ids
# Out:
# ['2CPqh63wRVscbceKcPxwvv',
#  '0Npijoc6ZcUe1devUugKvI',
#  '0Y9qJSwdV2LvPnFmAbNIc8',
#  '61ZM92T2zaXIVsqncThQzC',
#  '2rUsJXt4NeeDiIU6sBvrxo',
#  '09sKH3nKtVZ6ovDReYRAu0',
#  '2P4OICZRVAQcYAV2JReRfj',
#  '1gzXHWAGYKbaHubERNp0Ox',
#  '3IA89ROOb6QcQxFkviEs4e',
#  '7GXJdtlBmmuiatvyqb1KfT',
#  '7mrEifnAZ9uTP8qQvoBdKI',
#  '7hZeebyLqtLNLLVai4pNgi',
#  '2mrzerWjuLXvRCVOKoJfOs',
#  '3LVnspOfiC09yIaHCFJ1jd',
#  '12CEfIUwvPmInJCa40xy3J',
#  '1ptLWoNiWdgQftyyBI7hAy',
#  '3bPCSrkftQEdBQkG7s3mVd',
#  '4yYyidLY7wb22VEIL6Hzcj',
#  '2bR2OKgmJajgUdYmALlzdu',
#  '3d8k5cXwfK1Xp0fIIHr4k5',
#  '2s2zmSG9Mr71EZ3xURVdWm',
#  '2to3xwIngqZI0PTKTcteTv',
#  '1xErKvTvMqszpokp8Mr3Mq',
#  '2cpIZ0zfnlNNwk99Hmpwpn',
#  '0Nby3sP8ns6K37DsVCio5B',
#  '5fkM6vcniSGptmkxytFqMg',
#  '58hzFlHm1gKIJzRMSt0vWV']

# %%
playlist["total"]
# Out:
# 27

# %%
len(playlist["items"])
# Out:
# 27

# %%
artists_ids = get_artists_ids_from_playlist("5B7ozQ0Led4tEcXc4ql71j")
artists_ids
# Out:
# ['3t5xRXzsuZmMDkQzgOX35S',
#  '1vCWHaC5f2uS3yhpwWbIA6',
#  '4mVQMbJAHOazLrBmgpgB8M',
#  '4fdxbJLSNRIMkMGbLs5QPF',
#  '3whuHq0yGx60atvA2RCVRW',
#  '1mJNfK2yDxQ4GoxldvjvCE',
#  '6lB8vOoI4DRrrVxXwuV19c',
#  '17UkABEasVRlCcIFZ3wHb7',
#  '10hGPIDZi33LRaYRIq3Bh4',
#  '2q3GG88dVwuQPF4FmySr9I',
#  '647D92XNDYTUt5A0idePJ4',
#  '5tIkXJTex4JY7cv9mmgAZx',
#  '2LaNU9yZUvApYGMs7lw9bt',
#  '7eCmccnRwPmRnWPw61x6jM',
#  '2NpPlwwDVYR5dIj0F31EcC',
#  '3Cz6z3clgPkPz84faABaDS',
#  '4njdEjTnLfcGImKZu1iSrz',
#  '3GtCKJA4SkOxN65MWjm82R',
#  '3dTwqP9qJqFvVjcnKMbHu0',
#  '25MZxyt3nsEKGyDJQvb6HG',
#  '1Yj7SsIEP9k7SsE1HcMBrq',
#  '0NnlfSS9TzEUlffzx7KwBk',
#  '20gsENnposVs2I4rQ5kvrf',
#  '1kiq2kUV0cbLUhJsr7cpW0',
#  '5pXe6yFchq1oyYK3rq2A8i',
#  '4AKwRarlmsUlLjIwt38NLw',
#  '5OgSr6wQteRu9jek5JvnDQ',
#  '1t4zXUOD1mDn5Ng5cBe9oy',
#  '73jlPRxT7z5xk29sMqFDjU',
#  '799p2CSGw9GjO2X5pAB3ZH',
#  '7FUnhnuowTICdtK0KzH7Ng',
#  '09agIJMxCD2k87ys9Al0f0',
#  '38wxcfNEqMwuPniHvplin5',
#  '1mSJCvDX0W7Dn7S9C6vmvI',
# ...

# %%
sp.audio_features(track_ids[1])[0]
# Out:
# {'danceability': 0.654,
#  'energy': 0.787,
#  'key': 4,
#  'loudness': -4.999,
#  'mode': 1,
#  'speechiness': 0.0502,
#  'acousticness': 0.00515,
#  'instrumentalness': 0,
#  'liveness': 0.144,
#  'valence': 0.409,
#  'tempo': 123.978,
#  'type': 'audio_features',
#  'id': '0Npijoc6ZcUe1devUugKvI',
#  'uri': 'spotify:track:0Npijoc6ZcUe1devUugKvI',
#  'track_href': 'https://api.spotify.com/v1/tracks/0Npijoc6ZcUe1devUugKvI',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Npijoc6ZcUe1devUugKvI',
#  'duration_ms': 164490,
#  'time_signature': 4}

# %%
def analyze_playlist(creator, playlist_id):
    playlist_features_list = [
        "artist", "album", "track_name", "track_id", "danceability", "energy",
        "key", "loudness", "mode", "speechiness", "instrumentalness",
        "liveness", "valence", "tempo", "duration_ms", "time_signature"
    ]

    playlist_df = pd.DataFrame(columns=playlist_features_list)

    

    playlist = sp.user_playlist_tracks(creator, playlist_id)["items"]
    for track in playlist:
        # Create empty dict
        playlist_features = {}
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0][
            "name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]

        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]

        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index=[0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index=True)

    return playlist_df

# %%
playlist_df = analyze_playlist(playlist_creator, playlist_id)

# %%
playlist_df.head()
# Out:
#          artist                                      album  \
# 0    Mike Perry               The Ocean (feat. Shy Martin)
# 1     Hot Shade                                       Dive
# 2     Sam Feldt           Far Away From Home (feat. Leony)
# 3  Robin Schulz                 In Your Eyes (feat. Alida)
# 4  Robin Schulz  All We Got (feat. KIDDO) [Ofenbach Remix]
#
#                                   track_name                track_id  \
# 0               The Ocean (feat. Shy Martin)  2CPqh63wRVscbceKcPxwvv
# 1                                       Dive  0Npijoc6ZcUe1devUugKvI
# 2           Far Away From Home (feat. Leony)  0Y9qJSwdV2LvPnFmAbNIc8
# 3                 In Your Eyes (feat. Alida)  61ZM92T2zaXIVsqncThQzC
# 4  All We Got (feat. KIDDO) - Ofenbach Remix  2rUsJXt4NeeDiIU6sBvrxo
#
#    danceability  energy key  loudness mode  speechiness  instrumentalness  \
# 0         0.632   0.575   5    -6.478    1       0.0290          0.000002
# ...

# %%
data = playlist_df()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

X.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9320/1716953880.py in <module>
# ----> 1 data = playlist_df()
#       2
#       3 X = pd.DataFrame(data["data"], columns=data["feature_names"])
#       4 y = pd.Series(data["target"])
#       5
#
# TypeError: 'DataFrame' object is not callable

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X)

pd.DataFrame(X_prep).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9320/4139792303.py in <module>
#       1 from sklearn.preprocessing import StandardScaler
# ----> 2 X_prep = StandardScaler().fit_transform(X)
#       3
#       4 pd.DataFrame(X_prep).head()
#
# NameError: name 'X' is not defined

# %%
clusters = kmeans.predict(X_prep)
clusters
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9320/3730762290.py in <module>
# ----> 1 clusters = kmeans.predict(X_prep)
#       2 clusters
#
# NameError: name 'kmeans' is not defined
