# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://www.billboard.com/charts/hot-100"

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 5. retrieve/extract the desired info

# song titles
songs = soup.find_all("span", class_="chart-element__information__song text--truncate color--primary")

# artists
artists = soup.find_all("span", class_="chart-element__information__artist text--truncate color--secondary")

# last week
last_week_ranks = soup.find_all("span", class_= "chart-element__meta text--center color--secondary text--last")

# peak rank
peak_ranks = soup.find_all("span", class_= "chart-element__meta text--center color--secondary text--peak")

# weeks on chart
weeks_on_chart = soup.find_all("span", class_= "chart-element__meta text--center color--secondary text--week")

# %%
# 6. Get the text
for i in [songs, artists, last_week_ranks, peak_ranks, weeks_on_chart]:
    for j in range(len(i)):
        i[j] = i[j].getText()

# %%
# 7. Build a dataframe

billboard = pd.DataFrame(
    {"song": songs,
     "artist": artists,
     "last_week_rank": last_week_ranks,
     "peak_rank": peak_ranks,
     "weeks_on_chart": weeks_on_chart}
)
billboard
# Out:
#              song                                artist last_week_rank  \
# 0     My Universe                        Coldplay x BTS              -
# 1            Stay         The Kid LAROI & Justin Bieber              1
# 2   Industry Baby               Lil Nas X & Jack Harlow              2
# 3      Way 2 Sexy   Drake Featuring Future & Young Thug              3
# 4      Fancy Like                          Walker Hayes              5
# ..            ...                                   ...            ...
# 95      Pipe Down                                 Drake             68
# 96    Papi's Home                                 Drake             66
# 97         Chosen  Blxst & Tyga Featuring Ty Dolla $ign              -
# 98     Toxic Punk            YoungBoy Never Broke Again              -
# 99           Moon                            Kanye West             76
#
#    peak_rank weeks_on_chart
# 0          1              1
# 1          1             12
# 2          2             10
# 3          1              4
# 4          5             15
# ..       ...            ...
# 95        14              4
# 96         8              4
# 97        98              1
# 98        99              1
# 99        17              5
#
# [100 rows x 5 columns]

# %%
get_top_100 = billboard[["song",
     "artist",
     "last_week_rank",
     "peak_rank",
     "weeks_on_chart"]].head(50)

get_top_100
# Out:
#                               song  \
# 0                      My Universe
# 1                             Stay
# 2                    Industry Baby
# 3                       Way 2 Sexy
# 4                       Fancy Like
# 5                       Bad Habits
# 6                         Good 4 U
# 7                     Kiss Me More
# 8                       Knife Talk
# 9                       Levitating
# 10                         Essence
# 11                 Save Your Tears
# 12  Montero (Call Me By Your Name)
# 13                         Shivers
# 14                      Heat Waves
# 15                    Need To Know
# 16                Girls Want Girls
# 17                       You Right
# 18                         Beggin'
# 19                        Wockesha
# 20            If I Didn't Love You
# 21                  Take My Breath
# 22                      Fair Trade
# 23               Thats What I Want
# 24                         Traitor
# 25       Cold Beer Calling My Name
# 26               Chasing After You
# 27                     Bad Morning
# 28                           Pepas
# 29                         Deja Vu
# 30               Happier Than Ever
# 31                      Your Heart
# 32             Leave The Door Open
# 33                       Hurricane
# 34                           A-O-K
# 35                          Butter
# 36                      On My Side
# 37                        Too Easy
# 38        Leave Before You Love Me
# 39                        No Where
# 40                         Peaches
# 41                     Family Ties
# 42        Memory I Don't Mess With
# 43                   Late At Night
# 44        Things A Man Oughta Know
# 45         Cold Heart (PNAU Remix)
# 46             Meet Me At Our Spot
# 47                    Life Support
# 48        I Was On A Boat That Day
# 49        Love Nwantiti (Ah Ah Ah)
#
#                                             artist last_week_rank peak_rank  \
# 0                                   Coldplay x BTS              -         1
# 1                    The Kid LAROI & Justin Bieber              1         1
# 2                          Lil Nas X & Jack Harlow              2         2
# 3              Drake Featuring Future & Young Thug              3         1
# 4                                     Walker Hayes              5         5
# 5                                       Ed Sheeran              4         2
# 6                                   Olivia Rodrigo              6         1
# 7                           Doja Cat Featuring SZA              7         3
# 8          Drake Featuring 21 Savage & Project Pat              8         4
# 9                                         Dua Lipa             11         2
# 10           Wizkid Featuring Justin Bieber & Tems             14        11
# 11                      The Weeknd & Ariana Grande             12         1
# 12                                       Lil Nas X              9         1
# 13                                      Ed Sheeran             17        14
# 14                                   Glass Animals             16        15
# 15                                        Doja Cat             18        14
# 16                        Drake Featuring Lil Baby             13         2
# 17                           Doja Cat & The Weeknd             19        11
# 18                                        Maneskin             20        19
# 19                                    Moneybagg Yo             35        20
# 20                 Jason Aldean & Carrie Underwood             22        15
# 21                                      The Weeknd             21         6
# 22                    Drake Featuring Travis Scott             15         3
# 23                                       Lil Nas X             10        10
# 24                                  Olivia Rodrigo             25         9
# 25            Jameson Rodgers Featuring Luke Combs             29        26
# 26                     Ryan Hurd With Maren Morris             32        27
# 27                      YoungBoy Never Broke Again              -        28
# 28                                         Farruko             27        26
# 29                                  Olivia Rodrigo             23         3
# 30                                   Billie Eilish             28        11
# 31                          Joyner Lucas & J. Cole              -        32
# 32        Silk Sonic (Bruno Mars & Anderson .Paak)             33         1
# 33                                      Kanye West             31         6
# 34                                      Tai Verdes             39        35
# 35                                             BTS             24         1
# 36                      YoungBoy Never Broke Again             71        37
# 37                                  Gunna & Future              -        38
# 38                     Marshmello X Jonas Brothers             26        19
# 39                      YoungBoy Never Broke Again              -        40
# 40  Justin Bieber Featuring Daniel Caesar & Giveon             36         1
# 41                      Baby Keem & Kendrick Lamar             38        18
# 42                                       Lee Brice             54        43
# 43                                     Roddy Ricch             45        20
# 44                                   Lainey Wilson             34        32
# 45                           Elton John & Dua Lipa             74        46
# 46                THE ANXIETY: WILLOW & Tyler Cole             44        44
# 47                      YoungBoy Never Broke Again             79        48
# 48                                    Old Dominion             53        49
# 49                                            CKay             80        50
#
#    weeks_on_chart
# 0               1
# 1              12
# 2              10
# 3               4
# 4              15
# 5              14
# 6              20
# 7              25
# 8               4
# 9              52
# 10             13
# 11             42
# 12             27
# 13              3
# 14             37
# 15             16
# 16              4
# 17             14
# 18             14
# 19             23
# 20             10
# 21              8
# 22              4
# 23              2
# 24             19
# 25             13
# 26             22
# 27              1
# 28             10
# 29             26
# 30              9
# 31              1
# 32             30
# 33              5
# 34             13
# 35             19
# 36              2
# 37              1
# 38             19
# 39              1
# 40             28
# 41              5
# 42             10
# 43             17
# 44             20
# 45              4
# 46              3
# 47              3
# 48             13
# 49              2

# %%
user_song = input("What song do you like? ")
# Out:
# What song do you like? Butter

# %%
pos = -1
for index, song in enumerate(billboard['song'].tolist()):
    if song == user_song:
        pos = index

    if pos >=0:
        if pos == len(billboard)-1:
            print ('No next song in the list')
        else:
            print(billboard['song'].iloc[pos+1])
    else:
        print('no match found')
# Out:
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# no match found
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
# On My Side
